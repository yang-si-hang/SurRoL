# %%
import dvrk
import sys
import rospy
import numpy
import threading
import argparse
from sensor_msgs.msg import Joy
# from cisst_msgs.msg import prmCartesianImpedanceGains
from dvrk import mtm

m = mtm('MTML')

# %%
coag_event = threading.Event()
# foot pedal callback
def coag_event_cb(data):
    print('~~~',data)
    if (data.buttons[0] == 1):
        coag_event.set()
        print('clutched')
    else:
        print('not clutched',data.buttons[0])
rospy.Subscriber('footpedals/clutch',
                 Joy, coag_event_cb)
# Out:
# ~~~ header:
#   seq: 8
#   stamp:
#     secs: 1699364574
#     nsecs: 821544590
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699364581.346698]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699364581.349869]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699364581.352684]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 9
#   stamp:
#     secs: 1699364581
#     nsecs: 345308071
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 9
#   stamp:
#     secs: 1699364581
#     nsecs: 345308071
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# [ERROR] [1699365391.153199]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365391.157199]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365391.159884]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365391.164163]: bad callback: <function coag_event_cb at 0x7fcd10589430>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
#
# [ERROR] [1699365391.166742]: bad callback: <function coag_event_cb at 0x7fcd105890d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
# ~~~
# ~~~
# ~~~
# clutched
# ~~~ header:
#   seq: 10
#   stamp:
#     secs: 1699365391
#     nsecs: 150695186
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# ~~~ header:
#   seq: 10
#   stamp:
#     secs: 1699365391
#     nsecs: 150695186
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699365396.754937]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365396.758259]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365396.763350]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 11
#   stamp:
#     secs: 1699365396
#     nsecs: 753447984
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 11
#   stamp:
#     secs: 1699365396
#     nsecs: 753447984
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# [ERROR] [1699365401.106292]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365401.111213]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365401.113753]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365401.116453]: bad callback: <function coag_event_cb at 0x7fcd10589430>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
#
# [ERROR] [1699365401.119680]: bad callback: <function coag_event_cb at 0x7fcd105890d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
# ~~~
# ~~~
# ~~~
# clutched
# ~~~ header:
#   seq: 12
#   stamp:
#     secs: 1699365401
#     nsecs: 105149079
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# ~~~ header:
#   seq: 12
#   stamp:
#     secs: 1699365401
#     nsecs: 105149079
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699365405.583615]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365405.586817]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365405.590678]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 13
#   stamp:
#     secs: 1699365405
#     nsecs: 582353216
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 13
#   stamp:
#     secs: 1699365405
#     nsecs: 582353216
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# [ERROR] [1699365425.715558]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365425.720838]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365425.723660]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365425.726628]: bad callback: <function coag_event_cb at 0x7fcd10589430>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
#
# [ERROR] [1699365425.730778]: bad callback: <function coag_event_cb at 0x7fcd105890d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
# ~~~
# ~~~
# ~~~
# clutched
# ~~~ header:
#   seq: 14
#   stamp:
#     secs: 1699365425
#     nsecs: 714393425
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# ~~~ header:
#   seq: 14
#   stamp:
#     secs: 1699365425
#     nsecs: 714393425
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699365429.232598]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365429.236221]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365429.238419]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 15
#   stamp:
#     secs: 1699365429
#     nsecs: 230308321
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 15
#   stamp:
#     secs: 1699365429
#     nsecs: 230308321
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# [ERROR] [1699365437.038933]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365437.042836]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365437.045872]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365437.050461]: bad callback: <function coag_event_cb at 0x7fcd10589430>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
#
# [ERROR] [1699365437.053709]: bad callback: <function coag_event_cb at 0x7fcd105890d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
# ~~~
# ~~~
# ~~~
# clutched
# ~~~ header:
#   seq: 16
#   stamp:
#     secs: 1699365437
#     nsecs:  36377655
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# ~~~ header:
#   seq: 16
#   stamp:
#     secs: 1699365437
#     nsecs:  36377655
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699365439.371293]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365439.376646]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365439.379349]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 17
#   stamp:
#     secs: 1699365439
#     nsecs: 369928801
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 17
#   stamp:
#     secs: 1699365439
#     nsecs: 369928801
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# [ERROR] [1699365440.948798]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365440.952106]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365440.956447]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365440.959719]: bad callback: <function coag_event_cb at 0x7fcd10589430>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
#
# [ERROR] [1699365440.962114]: bad callback: <function coag_event_cb at 0x7fcd105890d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_44807/1861579587.py", line 6, in coag_event_cb
#     self.coag_event.set()
# NameError: name 'self' is not defined
# ~~~
# ~~~
# ~~~
# clutched
# ~~~ header:
#   seq: 18
#   stamp:
#     secs: 1699365440
#     nsecs: 947459950
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# ~~~ header:
#   seq: 18
#   stamp:
#     secs: 1699365440
#     nsecs: 947459950
#   frame_id: ''
# axes: []
# buttons: [1]
# clutched
# [ERROR] [1699365446.171613]: bad callback: <function coag_event_cb at 0x7fcd10e259d0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365446.173406]: bad callback: <function coag_event_cb at 0x7fcd105c9280>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
#
# [ERROR] [1699365446.174550]: bad callback: <function coag_event_cb at 0x7fcd10e4c940>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
# TypeError: coag_event_cb() missing 1 required positional argument: 'data'
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~
# not clutched 0
# ~~~ header:
#   seq: 19
#   stamp:
#     secs: 1699365446
#     nsecs: 170795891
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0
# ~~~ header:
#   seq: 19
#   stamp:
#     secs: 1699365446
#     nsecs: 170795891
#   frame_id: ''
# axes: []
# buttons: [0]
# not clutched 0

# %%
i=0
while i<250:
    coag_event.clear()
    coag_event.wait(1/250)
    i+=1
