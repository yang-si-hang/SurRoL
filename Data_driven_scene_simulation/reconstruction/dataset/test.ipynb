# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import numpy as np
from genPCD import genPLY
import open3d as o3d

# %%
depth = np.array(Image.open("/home/zhenya/dataset/81scenes/1/depth/0.png"))
rgb = np.array(Image.open("/home/zhenya/dataset/81scenes/1/0.png"))

# %%
plt.figure()
plt.imshow(depth)
plt.figure()
plt.imshow(rgb)

# %%
img = 255 - depth[...,0]
img.shape
# Out:
# (963, 1480)

# %%
plt.imshow(img,cmap='gray')
plt.colorbar()

# %%
lower_bound = np.percentile(img,5)
img[img<lower_bound]=lower_bound

# %%
genPLY('./', img, rgb)
pcd = o3d.io.read_point_cloud('./d_pcd.ply')
o3d.visualization.draw_geometries([pcd])
# Out:
# Image Shape 963, 1480
# Number of points: 213239
# The PLY file is generated.

# %% [markdown]
# ### Transform JPEG to PNG for Convenience

# %%
img = np.array(Image.open('/home/zhenya/dataset/81scenes/36/0.jpeg'))

# %%
Image.fromarray(img).save('/home/zhenya/dataset/81scenes/36/0.png')
